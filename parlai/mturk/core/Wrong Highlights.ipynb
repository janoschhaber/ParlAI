# %%
import os
import re
import json
import time
import datetime
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
from nltk import word_tokenize
from nltk.corpus import stopwords
import string
# %matplotlib inline

# %%
stop = stopwords.words('english') + list(string.punctuation)

# %%
def get_seconds(time_str):
    m, s = time_str.split(':')
    return int(m) * 60 + int(s)

def get_minutes(seconds):
    return seconds/60

def get_time_string(time_float):
    return datetime.datetime.utcfromtimestamp(time_float).strftime('%M:%S')

# %%
class Log:
    def __init__(self, logfile):
        self.game_id = logfile['game_id']
        self.domain_id = logfile['domain_id']
        self.agent_ids = list(logfile['disconnected'].keys())
        self.agent_labels = logfile['agent_labels']
        self.feedback = logfile['feedback']
        self.rounds = self.load_rounds(logfile['rounds'])
        self.score = self.calculate_score()
        self.duration = self.calculate_duration()
        self.domains = self.get_domains()
        self.calculate_timestamps()

    def load_rounds(self, game_rounds):
        rounds = []
        for round_data in game_rounds:
            game_round = GameRound(round_data)
            rounds.append(game_round)
        return rounds

    def calculate_score(self):
        score = 0
        for game_round in self.rounds:
            score += game_round.score
        return score
    
    def get_domains(self):
        path = self.rounds[0].images["A"][0][0].split("/")[0]
        return [domain for domain in path.split("_")]

    def calculate_timestamps(self):
        start_time = self.rounds[0].messages[0].timestamp
        for game_round in self.rounds:
            for mesage in game_round.messages:
                mesage.timestamp = datetime.datetime.utcfromtimestamp(mesage.timestamp - start_time)

    def calculate_duration(self):
        start_time = self.rounds[0].messages[0].timestamp
        end_time = self.rounds[-1].messages[-1].timestamp
        return get_time_string(end_time - start_time)


class GameRound:
    def __init__(self, logfile_entry):
        self.round_nr = logfile_entry['round_nr']+1
        self.images = logfile_entry['images']
        self.score = self.calculate_score(logfile_entry['score'])
        self.messages = self.load_messages(logfile_entry['messages'])
        self.num_messages = self.count_text_messages()
        self.duration = self.calculate_duration()

    def load_messages(self, message_list):
        messages = []
        message_id = 0
        for message_data in message_list:
            message = Message(message_data, message_id)
            messages.append(message)
            message_id += 1
        return messages

    def calculate_score(self, score_dict):
        score = 0
        for player_score in score_dict.values():
            score += player_score
        return score
    
    def count_text_messages(self):
        count = 0
        for message in self.messages:
            if message.type == "text":
                count += 1
        return count

    def calculate_duration(self):
        start_time = self.messages[0].timestamp
        end_time = self.messages[-1].timestamp
        return get_time_string(end_time - start_time)

class Message:
    def __init__(self, logfile_message, message_id):
        self.message_id = message_id
        self.agent_id = logfile_message['agent_id']
        self.agent_label = logfile_message['agent_label']
        self.text = logfile_message['message']
        self.speaker = logfile_message['speaker']
        self.timestamp = logfile_message['timestamp']
        self.turn = logfile_message['turn']
        self.type = self.determine_message_type()
        
    def determine_message_type(self):
        if not self.text.startswith("<"):
            return "text"
        else:
            return re.findall(r'<(.*?)>', self.text)[0]

# %%
def load_logs(filepath="logs/free_chat"):
    print("Loading logs from {}".format(filepath))
    logs = []
    for root, dirs, files in os.walk(filepath):
        for file in files:
            if file.endswith(".json"):
                # print("Loading {}".format(os.path.join(root, file)))
                with open(os.path.join(root, file), 'r') as logfile:
                    log = Log(json.load(logfile))
                    logs.append(log)

    print("Complete. Loaded {} logs.".format(len(logs)))
    return logs


def get_messages(log, split=False, print_selections=True):
    message_list = []
    if len(log.rounds) != 5:
        print("Conversation was not completed.")
        return []
    for game_round in log.rounds:
        round_messages = []
        for message in game_round.messages:
            if message.type == 'text' or (print_selections and message.type == 'selection') :   
                round_messages.append((message.timestamp, message.speaker, message.text))

        if split:
            message_list.append(round_messages)
        else:
            message_list.extend(round_messages)
    return message_list


def print_conversation(log, split=False, print_selections=True):
    message_list = get_messages(log, split, print_selections)
    
    print(log.game_id)
    print("Player A: {}".format(log.agent_ids[0]))
    print("Player B: {}".format(log.agent_ids[1]))
    
    
    if split:
        for i, round_messages in enumerate(message_list):
            print("- - Round {} - -".format(i+1))
            print_messages(round_messages)
    else:
        print_messages(message_list)
        
#     print(log.feedback)


def print_messages(message_list):
    for message in message_list:
        timestamp = message[0].strftime('%M:%S')
        print("[{}] {}: {}".format(timestamp, message[1], message[2]))


def print_game_statistics(log):
    print("\n- - Game statistics - -")
    print("Duration: {} min. Score: {}/30 points.".format(log.duration, log.score))
    for i, game_round in enumerate(log.rounds):
        print("[Round {}] Duration: {} min. Score: {}/6 points. Number of messages: {}.".format(i, game_round.duration, game_round.score, game_round.num_messages))

# %%
def collect_dataset(logs):
    labels = ["Game_ID", "Game_Domain_ID", "Game_Domain_1", "Game_Domain_2", "Game_Duration", "Game_Score", "Game_Feedback_A", "Game_Feedback_B", \
              "Round_Nr", "Round_Duration", "Round_Scores", "Round_Images_A", "Round_Images_B", \
              "Message_Nr", "Message_Timestamp", "Message_Turn", "Message_Agent_ID", "Message_Agent_Label", \
              "Message_Speaker", "Message_Type", "Message_Text"]
    dataset = []
    for log in logs:
        game_data = [log.game_id, log.domain_id, log.domains[0], log.domains[1], get_seconds(log.duration), log.score, log.feedback["A"], log.feedback["B"]]
        for game_round in log.rounds:
            round_data = [game_round.round_nr, get_seconds(game_round.duration), game_round.score, game_round.images["A"], game_round.images["B"]]
            for message in game_round.messages:
                message_data = [message.message_id, message.timestamp, message.turn, message.agent_id, message.agent_label, \
                                message.speaker, message.type, message.text] 
                dataset.append(game_data + round_data + message_data)
                
    df = pd.DataFrame(dataset, columns=labels)
                
    return df

# %%
path = "logs/wrong_highlights"

# %%
logs = load_logs(path)
nr_logs = len(logs)
for i, log in enumerate(logs):
    print("\n- - Game {} - -".format(i+1))
    print_conversation(log, split=True, print_selections=True)
    
    print_game_statistics(log)
# Out:
# Loading logs from logs/wrong_highlights
# Complete. Loaded 8 logs.
#
# - - Game 1 - -
# 3WYGZ5XF3XDUZS053ZX01TU9GSIKSO3IGI0VL648IG96TFTV879G1CDYKNOZ
# Player A: A2FL477TMKC91L
# Player B: A2RBF3IIJP15IH
# - - Round 1 - -
# [00:00] A: I have someone standing on a skateboard
# [00:20] B: I do, too. Is the skateboard green?
# [00:38] A: Yes, I have a man laying next to a suitcase and he looks flamboyant
# [01:15] B: I have him, too, but he isn't highlighted on my page.
# [01:15] A: <selection> <com> person_suitcase/COCO_train2014_000000538682.jpg
# [13:27] A: I definitely dont have that.
# [13:39] B: <selection> <dif> chair_couch/COCO_train2014_000000461340.jpg
# [13:58] B: okay differnt, what was your last one ?
# [13:58] A: <selection> <dif> chair_couch/COCO_train2014_000000410024.jpg
# [15:19] A: 1 red chair, 1 brown couch, living room and lsrge window showing with marble floor
# [16:33] B: I dont have that
# [17:15] A: okay ill submit
# [17:43] B: I submitted as well
# - - Round 2 - -
# [19:41] A: A picture of 2 people - one in a purple shirt male & 1 female blue shirt, next to a brown sofachair
# [20:12] B: I think I have that there are also 3 other people present?
# [21:40] A: Yes
# [21:45] B: <selection> <com> chair_couch/COCO_train2014_000000131927.jpg
# [22:34] B: ok, common. Living room, red floors but walls white. the couch in front of pic has some pink on it
# [22:34] A: <selection> <com> chair_couch/COCO_train2014_000000131927.jpg
# [23:34] A: is there a brown table next to the couch?
# [24:17] B: yes the table also has some things under the and on top
# [25:10] A: Yup i got that one
# [25:14] B: <selection> <com> chair_couch/COCO_train2014_000000581136.jpg
# [25:30] B: ok, was your 2nd one?
# [25:30] A: <selection> <com> chair_couch/COCO_train2014_000000581136.jpg
# [27:10] A: 2 striped couches, dark grey floor, brown walls,
# [28:26] B: dont have that, my last one has the ceiling with lights on top and a red square outside the window
# [29:52] A: ok, i didn't have that. ill submit
# [29:57] B: <selection> <dif> chair_couch/COCO_train2014_000000462712.jpg
# [30:04] B: submitted
# [30:04] A: <selection> <dif> chair_couch/COCO_train2014_000000461340.jpg
# - - Round 3 - -
# [31:44] A: 1vlarge tv, yellow blanket on top of a chair brown wood walls
# [32:28] B: dont have. I have 3 leather couch with book shelf and small tv. small table with red rug
# [33:06] A: <selection> <com> chair_couch/COCO_train2014_000000269431.jpg
# [33:07] A: <selection> <dif> chair_couch/COCO_train2014_000000119002.jpg
# [33:46] A: i got that one. last one is 2 large windows, fireplace, and 1 fireplace
# [33:46] B: <selection> <dif> chair_couch/COCO_train2014_000000341797.jpg
# [33:50] B: <selection> <com> chair_couch/COCO_train2014_000000269431.jpg
# [34:47] B: I think I have that. last one, 3 couch with red/black pillows table with laptop on top
# [35:40] A: i dont have that one.
# [35:40] B: <selection> <com> chair_couch/COCO_train2014_000000408925.jpg
# [35:45] B: <selection> <dif> chair_couch/COCO_train2014_000000408925.jpg
# [35:45] B: <selection> <dif> chair_couch/COCO_train2014_000000408925.jpg
# [35:54] B: <selection> <com> chair_couch/COCO_train2014_000000408925.jpg
# [35:54] B: <selection> <com> chair_couch/COCO_train2014_000000408925.jpg
# [35:56] B: ok, differnt. submitt
# [35:56] A: <selection> <dif> chair_couch/COCO_train2014_000000408925.jpg
# - - Round 4 - -
# [37:49] A: ok i have the picture of - "3 couch with red/black pillows table with laptop on top" that you said
# [38:24] B: me too, common. I have 3 leather couch, bookshelf, small tv,small table, red carpet from lsat time
# [38:24] A: <selection> <com> chair_couch/COCO_train2014_000000341797.jpg
# [39:46] A: dont have. i got 1 red couch chair, 1 brown couch, and marble floors
# [39:46] B: <selection> <com> chair_couch/COCO_train2014_000000341797.jpg
# [39:56] B: <selection> <dif> chair_couch/COCO_train2014_000000269431.jpg
# [39:58] B: <selection> <dif> chair_couch/COCO_train2014_000000269431.jpg
# [40:18] B: does it have towel over the red couch?
# [41:15] A: yes, that one and a large window at back
# [41:32] B: yes me too, that was my last one. so common.
# [41:52] A: <selection> <com> chair_couch/COCO_train2014_000000410024.jpg
# [42:44] A: Last pic is 2 large windows,  2 short green/brown wood chairs, 1 long green/brown sofa
# [42:44] B: <selection> <com> chair_couch/COCO_train2014_000000410024.jpg
# [43:12] B: I dont have that one I think I had it before
# [43:34] A: Ok lol, ill submit
# [43:53] B: submitted
# [43:53] A: <selection> <dif> chair_couch/COCO_train2014_000000408925.jpg
# - - Round 5 - -
# [45:37] A: i have same one as before - red couch chair, 1 brown couch, marble floors, with towel on red chair
# [46:19] B: yes me too, I have red floors, white walls couch closes has a pink thing on it next to brown table
# [46:52] A: <selection> <com> chair_couch/COCO_train2014_000000410024.jpg
# [48:02] A: I do not have that one, different. i have a bedroom - bed, 2 sofa chairs, tv, brown carpet floor
# [48:02] B: <selection> <com> chair_couch/COCO_train2014_000000410024.jpg
# [48:06] B: <selection> <dif> chair_couch/COCO_train2014_000000581136.jpg
# [48:56] B: is there a lamp next to the bed and a lamp next to the 2 sofas?
# [49:29] A: Yes
# [50:08] B: I have that, my last one is a picture in middle with flower vase under picture. There is 2 monitors
# [50:08] A: <selection> <com> chair_couch/COCO_train2014_000000512515.jpg
# [50:25] A: no i dont have
# [50:29] B: <selection> <dif> chair_couch/COCO_train2014_000000461340.jpg
# [50:35] B: ok, different
# [50:35] A: <selection> <dif> chair_couch/COCO_train2014_000000119002.jpg
# [51:57] A: my last one was the tv, brown couch chair with yellow blanket
# [52:21] B: I dont have that. I think we are finally done
# [52:52] A: ok submitted.
#
# - - Game statistics - -
# Duration: 53:18 min. Score: 26/30 points.
# [Round 0] Duration: 18:11 min. Score: 3/6 points. Number of messages: 12.
# [Round 1] Duration: 10:25 min. Score: 6/6 points. Number of messages: 12.
# [Round 2] Duration: 05:01 min. Score: 5/6 points. Number of messages: 6.
# [Round 3] Duration: 06:31 min. Score: 6/6 points. Number of messages: 10.
# [Round 4] Duration: 07:41 min. Score: 6/6 points. Number of messages: 11.
#
# - - Game 3 - -
# 38BQUHLA9XYARO8FHUT7W1CC88GOM63X08E93BHWGIDFHJUI0WQ5TZX8766P
# Player A: A3CTXNQ2GXIQSP
# Player B: A3KT7FHYY6PF2P
# - - Round 1 - -
# [00:00] A: I have a father and daughter sprinkling cheese onto a square pizza on the table
# [00:15] B: I have that. Do you have three military members one black two white standing by an open fridge?
# [00:43] A: No I do not. Do you have a woman facing the camera with a slice of pizza on a plate and a coke cup
# [00:43] B: <selection> <com> person_refrigerator/COCO_train2014_000000305451.jpg
# [00:46] B: <selection> <dif> person_refrigerator/COCO_train2014_000000040338.jpg
# [01:01] B: Yes. Do you have a girl standing up holding a pizza that appears to just have sauce on it
# [01:01] A: <selection> <com> person_refrigerator/COCO_train2014_000000305451.jpg
# [01:25] A: Is her mouth open and the fridge behind her is covered in magnets? If so yes.
# [01:50] B: Yes. Do you have a woman standing by a fridge in blue and a husband dude next to her with blue too?
# [06:05] B: ok.next a pizza with two glasses of beer is present
# [06:17] A: NOT HERE, MARK DIFFERENT
# [06:22] B: <selection> <dif> cup_dining_table/COCO_train2014_000000570019.jpg
# [06:30] B: ok.completed all
# [06:41] A: OK I SUBMIT
# [06:56] B: <selection> <dif> cup_dining_table/COCO_train2014_000000131498.jpg
# [07:19] B: i submitted
# - - Round 2 - -
# [07:51] A: BURGER WITH SAUCE AND DUMKIN DONUT
# [08:09] B: <selection> <com> cup_dining_table/COCO_train2014_000000035407.jpg
# [08:19] B: ya.present here,mark as common.highlighted here also
# [08:19] A: <selection> <com> cup_dining_table/COCO_train2014_000000035407.jpg
# [08:50] A: BLACK MUG DESIGNED WITH WHITE AND ONE ROASTED CAKE PRESENT
# [09:11] B: no black mug here.mark as different
# [09:11] A: <selection> <dif> cup_dining_table/COCO_train2014_000000304858.jpg
# [09:59] A: TEA IN WHITE CUP NAMED AXIS IN THE CUP NEARBY A CAKE IN BOX
# [10:28] B: yes present here.make as common
# [10:32] A: OK
# [10:32] B: <selection> <com> cup_dining_table/COCO_train2014_000000439518.jpg
# [11:03] B: two glass filled up with cookies present
# [11:03] A: <selection> <com> cup_dining_table/COCO_train2014_000000439518.jpg
# [11:08] A: NOT HERE
# [11:15] B: ok.
# [11:26] A: I M GOING TO SUBMIT
# [11:26] B: <selection> <dif> cup_dining_table/COCO_train2014_000000172135.jpg
# [11:35] B: ok.me too
# [11:55] A: COMPLETED SUBMIT
# [12:05] B: good work
# - - Round 3 - -
# [12:46] A: BLACK MUG WITH ROASTED CAKE WHERE SEEN ALREADY IN PREVIOUS PAGE
# [13:11] B: present.mark as common
# [13:11] A: <selection> <com> cup_dining_table/COCO_train2014_000000304858.jpg
# [13:18] A: OK
# [13:18] B: <selection> <com> cup_dining_table/COCO_train2014_000000304858.jpg
# [13:45] B: same mug named as axil is present
# [14:00] A: NOT HERE MARK DIFFERENT
# [14:21] B: ok.a glass full of cookies presnt
# [14:50] A: IS THE COOKIES ARE PRESENTED IN A WHITE TRAY
# [14:50] B: <selection> <dif> cup_dining_table/COCO_train2014_000000439518.jpg
# [15:07] B: yes.fine
# [15:24] A: OK MAKE COMMON
# [15:24] B: <selection> <com> cup_dining_table/COCO_train2014_000000172135.jpg
# [15:38] B: i did it.going to submit
# [15:38] A: <selection> <com> cup_dining_table/COCO_train2014_000000172135.jpg
# [15:44] A: HEY WAIT
# [15:58] B: ok.
# [16:14] A: HAVE U SEE ANY WHITE EMPTY MUG
# [16:28] B: no.mark different
# [16:32] A: OK
# [16:52] B: ok.
# [16:52] A: <selection> <dif> cup_dining_table/COCO_train2014_000000496196.jpg
# - - Round 4 - -
# [17:20] A: OK MOVE NEXT PAGE
# [17:46] B: a burger in a white plate present
# [18:18] A: YES, BUT IN THAT TOMATO SLICE AE PRESENT
# [18:36] B: yes.absolutely.make common
# [18:42] A: <selection> <com> cup_dining_table/COCO_train2014_000000038305.jpg
# [20:00] A: OK, PIZZA, NAMED AS JB SAUCE , TWO GLASSES OF BEER, AND A FORK PRESENTED
# [20:00] B: <selection> <com> cup_dining_table/COCO_train2014_000000038305.jpg
# [20:27] B: no such a sauce named JB,mark different
# [20:31] A: OK
# [21:15] B: a roll with french fries present here
# [21:15] A: <selection> <dif> cup_dining_table/COCO_train2014_000000570019.jpg
# [21:58] A: Ya ,IS THERE CHOCOLATE SHAKE AND RED SAUCE PRESENT
# [22:10] B: yes.mark common
# [22:17] A: <selection> <com> cup_dining_table/COCO_train2014_000000131498.jpg
# [22:35] A: OK I FINISHED SUBMIT
# [22:35] B: <selection> <com> cup_dining_table/COCO_train2014_000000131498.jpg
# [23:08] B: wait.two donuts with a chocolate shake present here
# [23:15] A: NO ,
# [23:25] B: <selection> <dif> cup_dining_table/COCO_train2014_000000105733.jpg
# [23:32] B: ok.
# [23:46] A: MOVE ON TO NEXT PAGE
# [23:57] B: nice work,
# - - Round 5 - -
# [25:18] A: BURGER WITH SAUCE AND DUMKIN DONUTS HAVE SSEN ALREADY PRESENT HERE
# [25:52] B: not here.mark different
# [26:31] A: OK , TWO GLASS OF BEER , PIZZA AND A jb NAMED SAUCE SEEN IN PREVIOUS PAGE
# [26:51] B: yes jb sauce present,mark common
# [26:51] A: <selection> <dif> cup_dining_table/COCO_train2014_000000035407.jpg
# [26:58] A: <selection> <com> cup_dining_table/COCO_train2014_000000570019.jpg
# [27:21] A: BURGER AND COFFEE IN A BLACK MUG
# [27:21] B: <selection> <com> cup_dining_table/COCO_train2014_000000570019.jpg
# [27:43] B: black mug has any design?
# [28:09] A: NO , A MAN HAVING FORK ON HIS LEFT HAND
# [28:26] B: no man here.mark different
# [28:44] A: OK, I FINISH
# [29:12] B: wait.is there axil named chocolate shake present?
# [29:12] A: <selection> <dif> cup_dining_table/COCO_train2014_000000316663.jpg
# [29:16] A: NO
# [29:21] B: <selection> <dif> cup_dining_table/COCO_train2014_000000439518.jpg
# [29:48] B: a glass full of cookies present there?
# [30:00] A: YES PRESENT HERE
# [30:02] B: <selection> <com> cup_dining_table/COCO_train2014_000000172135.jpg
# [30:10] B: i got finished
# [30:26] A: FINE
# [30:41] B: good job.
# [30:53] A: NICE
#
# - - Game statistics - -
# Duration: 31:37 min. Score: 30/30 points.
# [Round 0] Duration: 07:24 min. Score: 6/6 points. Number of messages: 14.
# [Round 1] Duration: 04:16 min. Score: 6/6 points. Number of messages: 14.
# [Round 2] Duration: 04:25 min. Score: 6/6 points. Number of messages: 16.
# [Round 3] Duration: 06:38 min. Score: 6/6 points. Number of messages: 16.
# [Round 4] Duration: 06:18 min. Score: 6/6 points. Number of messages: 17.
#
# - - Game 5 - -
# 3U5JL4WY5L7HH7X1CHG7TKM5YL4X4T3B1NLC6UG0USKEOULR8R8WX5MR4PGK
# Player A: A1N8TKTLXV92QR
# Player B: A2RUHO7I7Y4XFA
# - - Round 1 - -
# [00:00] A: I have a bear in a blue chair and a guy with a road kill cafe shirt next to it.
# [00:17] B: Don't have that
# [00:22] A: <selection> <dif> person_teddy_bear/COCO_train2014_000
# Player B: APD8A11HXR94C
# - - Round 1 - -
# [00:00] A: I have a room with black and white vertical stripe sofa and chairs with a tile floor
# [00:34] B: With four hot pink sofa pillows?
# [01:03] A: yes thats right.
# [01:10] B: I have that one.
# [01:10] A: <selection> <com> chair_couch/COCO_train2014_000000341797.jpg
# [03:16] A: In another one there is a red chair and cream sofa, on the sofa the is 2 cushion with red corners
# [03:16] B: <selection> <com> chair_couch/COCO_train2014_000000341797.jpg
# [04:09] B: Yes, I have that one. And a white sofa blanket on the red chair?
# [04:15] A: <selection> <com> chair_couch/COCO_train2014_000000410024.jpg
# [05:29] A: the next one has 2 chairs and a sofa, the arms of the are made of wood and it has a green patter on
# [05:29] B: <selection> <com> chair_couch/COCO_train2014_000000410024.jpg
# [05:53] B: Nope, don't have that.
# [05:59] A: <selection> <dif> chair_couch/COCO_train2014_000000408925.jpg
# [06:29] A: what about one with a gray TV?
# [06:36] B: Yes, I have that one.
# [06:53] A: dose it have a red rug on the floor?
# [07:14] B: Yes, and a huge window covering the whole wall.
# [08:13] A: Do you have one with glass doors at the back of the room?
# [08:37] B: No, I don't see that.
# [08:58] A: Any other questions?
# [09:41] B: Yes, last one for me, three leather couches with dimples all over, 2 love seats, 1 regular sofa?
# [10:07] A: No i dont have that one
# [10:10] B: Okay.
# [12:02] A: I have submitted mine
# [12:02] B: <selection> <dif> chair_couch/COCO_train2014_000000269431.jpg
# [12:11] B: Same, next page.
# - - Round 2 - -
# [12:57] A: I have one with a big widescreen tv
# [13:16] B: I don't have that one.
# [13:23] A: <selection> <dif> chair_couch/COCO_train2014_000000119002.jpg
# [14:18] A: I have the same one with the red chair and cream sofa
# [15:06] B: I see the grey chair with the two pillows with pink corners. But no cream sofa.
# [16:20] A: its got a red chair with a blanket over the back
# [16:43] B: Okay. And the pillows with pink corners?
# [16:52] A: yes
# [16:55] B: <selection> <com> chair_couch/COCO_train2014_000000410024.jpg
# [18:04] B: I see a large open living room with two white pillars with red at their bases.
# [18:04] A: <selection> <com> chair_couch/COCO_train2014_000000410024.jpg
# [18:30] A: no i don't have that one
# [18:48] B: <selection> <dif> chair_couch/COCO_train2014_000000581136.jpg
# [19:43] B: Now I see a room with 1 brown striped love seat and full couch with a painting on wall between them
# [20:30] A: no i dont have that one
# [20:44] B: Okay, that's it for me. YOu're turn.
# [21:37] A: I have a room there is a Tv in the back ground a double bed and 2 lamps one is turned on
# [21:37] B: <selection> <dif> chair_couch/COCO_train2014_000000461340.jpg
# [21:54] B: Yes I have that one.
# [21:58] A: <selection> <com> chair_couch/COCO_train2014_000000512515.jpg
# [22:20] A: I'm done
# [22:26] B: Kay, next
# [24:18] A: Any other Questions? I've submitted
# [24:27] B: None, next.
# - - Round 3 - -
# [25:11] A: I have a photo with 3 people playing a game
# [25:37] B: Yes.
# [27:38] A: i have one with the 2 red leather seats and sofa with dimples and a book shelf in the background
# [27:50] B: Yep, me too.
# [28:14] A: <selection> <com> chair_couch/COCO_train2014_000000269431.jpg
# [28:59] A: I ave on with a large widescreen tv with a Guitar at the side of it
# [31:53] B: <selection> <com> chair_couch/COCO_train2014_000000269431.jpg
# [32:10] B: Sorry,  button froze had to refresh.  And no, don't have that one.
# [32:20] A: <selection> <dif> chair_couch/COCO_train2014_000000119002.jpg
# [33:19] A: Next on i have there is a sofa and 2 chairs with wooden arms and it has a green patten
# [33:39] B: Yes.
# [33:43] A: <selection> <com> chair_couch/COCO_train2014_000000408925.jpg
# [34:06] A: I done do you have any questions?
# [34:06] B: <selection> <com> chair_couch/COCO_train2014_000000408925.jpg
# [34:27] B: Yep, 1, the four hot pink sofa pillows?
# [34:45] A: no dont have that
# [34:49] B: <selection> <dif> chair_couch/COCO_train2014_000000341797.jpg
# [34:57] B: Okay, submitting.
# [36:34] A: Ok I've submitted
# - - Round 4 - -
# [37:40] A: first one is the three people playing a game
# [37:47] B: Yes, got it.
# [37:50] A: <selection> <com> chair_couch/COCO_train2014_000000131927.jpg
# [39:12] A: the next on has a brown carpet striped sofa and chair and there is stuff on the floor
# [39:12] B: <selection> <com> chair_couch/COCO_train2014_000000131927.jpg
# [39:38] B: Nope.
# [39:42] A: <selection> <dif> chair_couch/COCO_train2014_000000461340.jpg
# [40:22] A: I have one and the is a red shiny floor and i can see 6 pictures on the back wall
# [40:35] B: Yes, with the white pillars.
# [40:42] A: yes
# [40:49] B: <selection> <com> chair_couch/COCO_train2014_000000581136.jpg
# [41:58] B: 1 for me, a room with two wooden glass doors and looking through the doors you can see a red door.
# [41:58] A: <selection> <com> chair_couch/COCO_train2014_000000581136.jpg
# [42:17] A: no i dont have that
# [42:20] B: Okay.
# [42:40] A: Im done any more questions?
# [42:40] B: <selection> <dif> chair_couch/COCO_train2014_000000462712.jpg
# [42:48] B: Same, submitting.
# [43:07] A: Ok I've submitted
# - - Round 5 - -
# [43:47] A: Same one with the red chair with the blanket
# [43:53] B: Nope.
# [43:56] A: <selection> <dif> chair_couch/COCO_train2014_000000410024.jpg
# [44:41] A: one withe the striped chair and sofa with stuff on the floor and a picture on the wall
# [45:01] B: Yes, there's  silver apple laptop on teh floor too.
# [45:06] A: <selection> <com> chair_couch/COCO_train2014_000000461340.jpg
# [45:09] A: yes
# [45:09] B: <selection> <com> chair_couch/COCO_train2014_000000461340.jpg
# [45:26] B: Okay, the four hot pink sofa pillows.
# [46:08] A: no dont have that
# [46:10] B: <selection> <dif> chair_couch/COCO_train2014_000000341797.jpg
# [46:35] B: Okay, 3 leather couches with dimples all over, 2 of them love seats, 1 full size?
# [46:47] A: yes i have that
# [46:49] B: <selection> <com> chair_couch/COCO_train2014_000000269431.jpg
# [47:00] B: Okay. I'm done, you're up.
# [47:41] A: one with an old CRT TV with a really big window and a red rug on the floor
# [47:58] B: Nope. Not  that one.
# [48:03] A: <selection> <dif> chair_couch/COCO_train2014_000000002347.jpg
# [48:16] A: Im done ive submitted
# [48:23] B: Okay. Same.
# [48:39] A: Ok
# [48:58] B: We make a great team Kelsey!
#
# - - Game statistics - -
# Duration: 49:30 min. Score: 30/30 points.
# [Round 0] Duration: 12:15 min. Score: 6/6 points. Number of messages: 20.
# [Round 1] Duration: 11:32 min. Score: 6/6 points. Number of messages: 18.
# [Round 2] Duration: 11:27 min. Score: 6/6 points. Number of messages: 13.
# [Round 3] Duration: 05:30 min. Score: 6/6 points. Number of messages: 13.
# [Round 4] Duration: 05:42 min. Score: 6/6 points. Number of messages: 16.

# %%
dataset = collect_dataset(logs)
dataset.columns
# Out:
# Index(['Game_ID', 'Game_Domain_ID', 'Game_Domain_1', 'Game_Domain_2',
#        'Game_Duration', 'Game_Score', 'Game_Feedback_A', 'Game_Feedback_B',
#        'Round_Nr', 'Round_Duration', 'Round_Scores', 'Round_Images_A',
#        'Round_Images_B', 'Message_Nr', 'Message_Timestamp', 'Message_Turn',
#        'Message_Agent_ID', 'Message_Agent_Label', 'Message_Speaker',
#        'Message_Type', 'Message_Text'],
#       dtype='object')

# %%
dataset.to_csv('conversations.csv', index = False)

# %%
dataset.to_pickle('conversations.pickle')

# %%
game_times = dataset.groupby('Game_ID').mean()['Game_Duration']
game_times_list = [get_minutes(duration) for duration in list(game_times)]
print(game_times_list)
# Out:
# [31.616666666666667, 13.533333333333333, 49.5, 42.633333333333333, 34.333333333333336, 25.350000000000001, 18.666666666666668, 53.299999999999997]

# %%
print(np.mean(game_times_list))
# Out:
# 33.6166666667

# %%
plt.hist(game_times_list, bins=np.linspace(10,60,50), weights=np.zeros_like(game_times_list) + 100. / len(game_times_list))  # arguments are passed to np.histogram
plt.title("Distribution of Game Durations")
plt.xlabel("Duration in min")
plt.ylabel("% of the completed Games")
plt.draw()
ax = plt.gca()
xticks = [str(label.get_text())+" min" for label in ax.get_xticklabels()][1:-1]
ax.set_xticklabels = xticks
plt.draw()
plt.show()

# %%
games_df = dataset.groupby('Game_ID')

# %%
game_statistics = defaultdict(lambda: (defaultdict(lambda: [])))

for game_df in games_df:
#     print("Game {}".format(game_df[0]))
    rounds_df = game_df[1].groupby('Round_Nr')
    for round_df in rounds_df:
#         print("Round {}".format(round_df[0]))
        player_data_df = round_df[1].groupby('Message_Agent_ID')
        token_sum = 0
        message_sum = 0
        for player_df in player_data_df:
            
            messages = player_df[1].loc[player_df[1]['Message_Type'] == 'text']
            message_list = messages['Message_Text'].tolist()
            no_tokens = 0
            for m in message_list:
                tokens = [i for i in word_tokenize(m.lower()) if i not in stop]
#                 print(tokens)
#                 print(len(tokens))
                no_tokens += len(tokens)
            token_sum += no_tokens
            message_sum += len(message_list)
#             print("Agent {} used {} tokens in {} messages.".format(player_df[0], no_tokens, len(message_list)))
            
        game_statistics["tokens"][round_df[0]].append(token_sum)
        game_statistics["messages"][round_df[0]].append(message_sum)
        game_statistics["duration"][round_df[0]].append(round_df[1].mean()["Round_Duration"])
#         print("Total tokens: {}. Total messages: {}. Duration: {}".format(token_sum, message_sum, get_time_string(round_df[1].mean()["Round_Duration"])))
#     print("\n-------\n")

# %%
def plot_game_data(mu, sigma, t, title, x_label, y_label, filename=None):
    fig, ax = plt.subplots(1, figsize=(10,6))
    ax.plot(t, mu, lw=2, label='mean population 1', color='blue')
    ax.fill_between(t, mu+sigma, mu-sigma, facecolor='blue', alpha=0.3)
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.set_xticks(t)
    ax.grid()
    fig.show()
    if filename:
        fig.savefig(filename, bbox_inches='tight')

# %%
data_array = np.empty([5, nr_logs])

for round_nr, token_counts in game_statistics["tokens"].items():    
    print("Round {}: Token counts {}".format(round_nr, token_counts))
    data_array[round_nr-1] = token_counts
    
mu = data_array.mean(axis=1)
sigma = data_array.std(axis=1)
t = np.arange(1, 6, 1)

title = 'Average number of Word Tokens per Game Round'
x_label = 'Game Round'
y_label = 'Total number of Word Tokens (both Speakers)'
filename = 'tokens.pdf'


plot_game_data(mu, sigma, t, title, x_label, y_label, filename)
# Out:
# Round 1: Token counts [49, 67, 91, 48, 51, 47, 53, 88]
# Round 2: Token counts [47, 36, 80, 71, 42, 70, 29, 70]
# Round 3: Token counts [44, 56, 53, 38, 51, 61, 30, 46]
# Round 4: Token counts [57, 32, 50, 66, 45, 41, 55, 70]
# Round 5: Token counts [60, 41, 67, 75, 39, 39, 45, 69]
# /home/janosch/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
data_array = np.empty([5, nr_logs])

for round_nr, token_counts in game_statistics["messages"].items():    
    print("Round {}: Message counts {}".format(round_nr, token_counts))
    data_array[round_nr-1] = token_counts
    
mu = data_array.mean(axis=1)
sigma = data_array.std(axis=1)
t = np.arange(1, 6, 1)

title = 'Average number of Messages per Game Round'
x_label = 'Game Round'
y_label = 'Total number of Messages (both Speakers)'
filename = 'messages.pdf'


plot_game_data(mu, sigma, t, title, x_label, y_label, filename)
# Out:
# Round 1: Message counts [14, 12, 20, 14, 11, 13, 10, 12]
# Round 2: Message counts [14, 6, 18, 19, 11, 17, 9, 12]
# Round 3: Message counts [16, 10, 13, 12, 13, 14, 8, 6]
# Round 4: Message counts [16, 8, 13, 18, 13, 11, 11, 10]
# Round 5: Message counts [17, 8, 16, 22, 15, 13, 8, 11]
# /home/janosch/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
data_array = np.empty([5, nr_logs])

for round_nr, token_counts in game_statistics["duration"].items():    
    print("Round {}: Duration {}".format(round_nr, token_counts))
    data_array[round_nr-1] = token_counts
    
mu = data_array.mean(axis=1)
sigma = data_array.std(axis=1)
t = np.arange(1, 6, 1)

title = 'Average duration per Game Round in seconds'
x_label = 'Game Round'
y_label = 'Total Round duration in seconds'
filename = 'duration.pdf'


plot_game_data(mu, sigma, t, title, x_label, y_label, filename)
# Out:
# Round 1: Duration [444.0, 202.0, 735.0, 507.0, 538.0, 410.0, 262.0, 1091.0]
# Round 2: Duration [256.0, 123.0, 692.0, 495.0, 342.0, 327.0, 167.0, 625.0]
# Round 3: Duration [265.0, 190.0, 687.0, 288.0, 373.0, 234.0, 139.0, 301.0]
# Round 4: Duration [398.0, 97.0, 330.0, 500.0, 334.0, 165.0, 267.0, 391.0]
# Round 5: Duration [378.0, 113.0, 342.0, 618.0, 289.0, 265.0, 226.0, 461.0]
# /home/janosch/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
for game_id, game_df in games_df:
    selections = game_df.loc[game_df['Message_Type'] == 'selection']['Message_Text']
    sel_images = [elements.split()[2] for elements in selections]
    print(len(set(sel_images)))
# Out:
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
